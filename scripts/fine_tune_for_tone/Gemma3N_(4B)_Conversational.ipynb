# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Read our **[Gemma 3N Guide](https://docs.unsloth.ai/basics/gemma-3n-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth

# %%
# %%capture
# Install latest transformers for Gemma 3N
# !pip install --no-deps --upgrade timm # Only for Gemma 3N

# %%
import os

cache_dir = os.path.expanduser("~/.cache/huggingface/hub")
print(f"Cache directory: {cache_dir}")

import shutil

free_space = shutil.disk_usage(cache_dir).free / (1024**3)
print(f"Free space: {free_space:.2f} GB")
# Out:
# Cache directory: /home/tyler/.cache/huggingface/hub
# Free space: 357.34 GB

# %%
from unsloth import FastModel

model, tokenizer = FastModel.from_pretrained(
    model_name="unsloth/gemma-3-1b-it-unsloth-bnb-4bit",
    dtype=None,
    max_seq_length=1024,
    load_in_4bit=True,
    force_download=True,  # Add this
    full_finetuning=False,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.8.1: Fast Gemma3 patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA GeForce RTX 3060. Num GPUs = 1. Max memory: 11.622 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu126. CUDA: 8.6. CUDA Toolkit: 12.6. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]

# %% [markdown]
# ### Unsloth
#
# `FastModel` supports loading nearly any model now! This includes Vision and Text models!

# %%
from unsloth import FastModel
import torch
from tqdm import tqdm
import os

os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3n-E4B-it-unsloth-bnb-4bit",
    "unsloth/gemma-3n-E2B-it-unsloth-bnb-4bit",
    # Pretrained models
    "unsloth/gemma-3n-E4B-unsloth-bnb-4bit",
    "unsloth/gemma-3n-E2B-unsloth-bnb-4bit",
    # Other Gemma 3 quants
    "unsloth/gemma-3-1b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",
]  # More models at https://huggingface.co/unsloth

model, tokenizer = FastModel.from_pretrained(
    model_name="unsloth/gemma-3-1b-it-unsloth-bnb-4bit",
    dtype=None,  # None for auto detection
    max_seq_length=1024,  # Choose any for long context!
    load_in_4bit=True,  # 4 bit quantization to reduce memory
    full_finetuning=False,  # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.8.1: Fast Gemma3 patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA GeForce RTX 3060. Num GPUs = 1. Max memory: 11.622 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu126. CUDA: 8.6. CUDA Toolkit: 12.6. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.00G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/python/agents/agents/lib/python3.12/site-packages/huggingface_hub/file_download.py:629, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     627     progress.update(progress_bytes)
# --> 629 download_files(
#     630     xet_download_info,
#     631     endpoint=connection_info.endpoint,
#     632     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     633     token_refresher=token_refresher,
#     634     progress_updater=[progress_updater],
#     635 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 22
#       6 os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
#       8 fourbit_models = [
#       9     # 4bit dynamic quants for superior accuracy and low memory use
#      10     "unsloth/gemma-3n-E4B-it-unsloth-bnb-4bit",
#    (...)     19     "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",
#      20 ]  # More models at https://huggingface.co/unsloth
# ---> 22 model, tokenizer = FastModel.from_pretrained(
#      23     model_name="unsloth/gemma-3-1b-it-unsloth-bnb-4bit",
#      24     dtype=None,  # None for auto detection
#      25     max_seq_length=1024,  # Choose any for long context!
#      26     load_in_4bit=True,  # 4 bit quantization to reduce memory
#      27     full_finetuning=False,  # [NEW!] We have full finetuning now!
#      28     # token = "hf_...", # use one if using gated models
#      29 )
#
# File ~/python/agents/agents/lib/python3.12/site-packages/unsloth/models/loader.py:797, in FastModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, load_in_8bit, full_finetuning, token, device_map, rope_scaling, fix_tokenizer, trust_remote_code, use_gradient_checkpointing, resize_model_vocab, revision, return_logits, fullgraph, use_exact_model_name, auto_model, whisper_language, whisper_task, unsloth_force_compile, *args, **kwargs)
#     794 if auto_model is None:
#     795     auto_model = AutoModelForVision2Seq if is_vlm else AutoModelForCausalLM
# --> 797 model, tokenizer = FastBaseModel.from_pretrained(
#     798     model_name        = model_name,
#     799     max_seq_length    = max_seq_length,
#     800     dtype             = _get_dtype(dtype),
#     801     load_in_4bit      = load_in_4bit,
#     802     load_in_8bit      = load_in_8bit,
#     803     full_finetuning   = full_finetuning,
#     804     token             = token,
#     805     device_map        = device_map,
#     806     trust_remote_code = trust_remote_code,
#     807     revision          = revision if not is_peft else None,
#     808     model_types       = model_types,
#     809     tokenizer_name    = tokenizer_name,
#     810     auto_model        = auto_model,
#     811     use_gradient_checkpointing = use_gradient_checkpointing,
#     812     supports_sdpa     = supports_sdpa,
#     813     whisper_language  = whisper_language,
#     814     whisper_task      = whisper_task,
#     815     *args, **kwargs,
#     816 )
#     818 if resize_model_vocab is not None:
#     819     model.resize_token_embeddings(resize_model_vocab)
#
# File ~/python/agents/agents/lib/python3.12/site-packages/unsloth/models/vision.py:430, in FastBaseModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, load_in_8bit, full_finetuning, token, device_map, trust_remote_code, model_types, tokenizer_name, auto_model, use_gradient_checkpointing, supports_sdpa, whisper_language, whisper_task, **kwargs)
#     427 if do_forced_float32: torch_dtype = torch.bfloat16
#     429 raise_handler = RaiseUninitialized()
# --> 430 model = auto_model.from_pretrained(
#     431     model_name,
#     432     device_map              = device_map,
#     433     torch_dtype             = torch_dtype,
#     434     # quantization_config   = bnb_config,
#     435     token                   = token,
#     436     trust_remote_code       = trust_remote_code,
#     437     # attn_implementation   = attn_implementation,
#     438     **kwargs,
#     439 )
#     440 raise_handler.remove()
#     441 # Return old flag
#
# File ~/python/agents/agents/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     606 )
#
# File ~/python/agents/agents/lib/python3.12/site-packages/transformers/modeling_utils.py:315, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     313 old_dtype = torch.get_default_dtype()
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 finally:
#     317     torch.set_default_dtype(old_dtype)
#
# File ~/python/agents/agents/lib/python3.12/site-packages/transformers/modeling_utils.py:4854, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4844 if (
#    4845     gguf_file
#    4846     and device_map is not None
#    4847     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4848 ):
#    4849     raise RuntimeError(
#    4850         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4851         "loaded from GGUF files."
#    4852     )
# -> 4854 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4855     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4856     subfolder=subfolder,
#    4857     variant=variant,
#    4858     gguf_file=gguf_file,
#    4859     from_tf=from_tf,
#    4860     from_flax=from_flax,
#    4861     use_safetensors=use_safetensors,
#    4862     cache_dir=cache_dir,
#    4863     force_download=force_download,
#    4864     proxies=proxies,
#    4865     local_files_only=local_files_only,
#    4866     token=token,
#    4867     user_agent=user_agent,
#    4868     revision=revision,
#    4869     commit_hash=commit_hash,
#    4870     is_remote_code=cls._auto_class is not None,
#    4871     transformers_explicit_filename=transformers_explicit_filename,
#    4872 )
#    4874 is_sharded = sharded_metadata is not None
#    4875 is_quantized = hf_quantizer is not None
#
# File ~/python/agents/agents/lib/python3.12/site-packages/transformers/modeling_utils.py:1141, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1126 try:
#    1127     # Load from URL or cache if already cached
#    1128     cached_file_kwargs = {
#    1129         "cache_dir": cache_dir,
#    1130         "force_download": force_download,
#    (...)   1139         "_commit_hash": commit_hash,
#    1140     }
# -> 1141     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    1143     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    1144     # result when internet is up, the repo and revision exist, but the file does not.
#    1145     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    1146         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/python/agents/agents/lib/python3.12/site-packages/transformers/utils/hub.py:318, in cached_file(path_or_repo_id, filename, **kwargs)
#     260 def cached_file(
#     261     path_or_repo_id: Union[str, os.PathLike],
#     262     filename: str,
#     263     **kwargs,
#     264 ) -> Optional[str]:
#     265     """
#     266     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     267
#    (...)    316     ```
#     317     """
# --> 318     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     319     file = file[0] if file is not None else file
#     320     return file
#
# File ~/python/agents/agents/lib/python3.12/site-packages/transformers/utils/hub.py:476, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     473 try:
#     474     if len(full_filenames) == 1:
#     475         # This is slightly better for only 1 file
# --> 476         hf_hub_download(
#     477             path_or_repo_id,
#     478             filenames[0],
#     479             subfolder=None if len(subfolder) == 0 else subfolder,
#     480             repo_type=repo_type,
#     481             revision=revision,
#     482             cache_dir=cache_dir,
#     483             user_agent=user_agent,
#     484             force_download=force_download,
#     485             proxies=proxies,
#     486             resume_download=resume_download,
#     487             token=token,
#     488             local_files_only=local_files_only,
#     489         )
#     490     else:
#     491         snapshot_download(
#     492             path_or_repo_id,
#     493             allow_patterns=full_filenames,
#    (...)    502             local_files_only=local_files_only,
#     503         )
#
# File ~/python/agents/agents/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/python/agents/agents/lib/python3.12/site-packages/huggingface_hub/file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#    (...)   1007         local_files_only=local_files_only,
#    1008     )
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File ~/python/agents/agents/lib/python3.12/site-packages/huggingface_hub/file_download.py:1171, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1168 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1170 with WeakFileLock(lock_path):
# -> 1171     _download_to_tmp_and_move(
#    1172         incomplete_path=Path(blob_path + ".incomplete"),
#    1173         destination_path=Path(blob_path),
#    1174         url_to_download=url_to_download,
#    1175         proxies=proxies,
#    1176         headers=headers,
#    1177         expected_size=expected_size,
#    1178         filename=filename,
#    1179         force_download=force_download,
#    1180         etag=etag,
#    1181         xet_file_data=xet_file_data,
#    1182     )
#    1183     if not os.path.exists(pointer_path):
#    1184         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/python/agents/agents/lib/python3.12/site-packages/huggingface_hub/file_download.py:1723, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1721 if xet_file_data is not None and is_xet_available():
#    1722     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1723     xet_get(
#    1724         incomplete_path=incomplete_path,
#    1725         xet_file_data=xet_file_data,
#    1726         headers=headers,
#    1727         expected_size=expected_size,
#    1728         displayed_filename=filename,
#    1729     )
#    1730 else:
#    1731     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/python/agents/agents/lib/python3.12/site-packages/huggingface_hub/file_download.py:624, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     613     displayed_filename = f"{displayed_filename[:40]}(…)"
#     615 progress_cm = _get_progress_bar_context(
#     616     desc=displayed_filename,
#     617     log_level=logger.getEffectiveLevel(),
#    (...)    621     _tqdm_bar=_tqdm_bar,
#     622 )
# --> 624 with progress_cm as progress:
#     626     def progress_updater(progress_bytes: float):
#     627         progress.update(progress_bytes)
#
# File ~/python/agents/agents/lib/python3.12/site-packages/tqdm/std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:

# %% [markdown]
# # Gemma 3N can process Text, Vision and Audio!
#
# Let's first experience how Gemma 3N can handle multimodal inputs. We use Gemma 3N's recommended settings of `temperature = 1.0, top_p = 0.95, top_k = 64`

# %%
from transformers import TextStreamer


# Helper function for inference
def do_gemma_3n_inference(messages, max_new_tokens=128):
    _ = model.generate(
        **tokenizer.apply_chat_template(
            messages,
            add_generation_prompt=True,  # Must add for generation
            tokenize=True,
            return_dict=True,
            return_tensors="pt",
        ).to("cuda"),
        max_new_tokens=max_new_tokens,
        temperature=1.0,
        top_p=0.95,
        top_k=64,
        streamer=TextStreamer(tokenizer, skip_prompt=True),
    )

# %% [markdown]
# # Gemma 3N can see images!
#
# <img src="https://files.worldwildlife.org/wwfcmsprod/images/Sloth_Sitting_iStock_3_12_2014/story_full_width/8l7pbjmj29_iStock_000011145477Large_mini__1_.jpg" alt="Alt text" height="256">

# %%
sloth_link = "https://files.worldwildlife.org/wwfcmsprod/images/Sloth_Sitting_iStock_3_12_2014/story_full_width/8l7pbjmj29_iStock_000011145477Large_mini__1_.jpg"

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "what is 22/7?"},
        ],
    }
]
# You might have to wait 1 minute for Unsloth's auto compiler
do_gemma_3n_inference(messages, max_new_tokens=256)
# Out:
# 22/7 is approximately 3.142857...
#
# This is a fraction, and it's an irrational number, meaning its decimal representation goes on infinitely without repeating.
#
# It's a special number because it's the reciprocal of 33/22, which is also irrational.
#
# You can express it as:
#
# *   33/22 * (22/33)
# *   22/7 * (33/22)
#
# It's a fascinating number!
# <end_of_turn>

# %% [markdown]
# Let's make a poem about sloths!

# %%
messages = [
    {
        "role": "user",
        "content": [{"type": "text", "text": "Write a poem about sloths."}],
    }
]
do_gemma_3n_inference(messages)
# Out:
# Okay, here's a poem about sloths, aiming for a slightly whimsical and peaceful tone:
#
# **The Velvet Anchor**
#
# Upon a branch, a verdant throne,
# A sloth hangs still, utterly alone.
# Green fur draped, a slow, soft hue,
# A silent rhythm, peaceful and true.
#
# No hurried steps, no frantic pace,
# Just languid breaths within this place.
# A leaf, a sunbeam, warmth to seize,
# A moment held, a gentle peace.
#
# The world speeds past, a blurry sight,
# They watch the leaves in golden light.
# No need to move

# %% [markdown]
# # Gemma 3N can also hear!

# %%
from IPython.display import Audio, display

Audio("https://www.nasa.gov/wp-content/uploads/2015/01/591240main_JFKmoonspeech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !wget -qqq https://www.nasa.gov/wp-content/uploads/2015/01/591240main_JFKmoonspeech.mp3 -O audio.mp3

# %%
audio_file = "audio.mp3"

messages = [
    {
        "role": "user",
        "content": [
            {"type": "audio", "audio": audio_file},
            {"type": "text", "text": "What is this audio about?"},
        ],
    }
]
do_gemma_3n_inference(messages, max_new_tokens=256)
# Out:
# The audio is a quote from President John F. Kennedy's famous speech to Congress on May 25, 1961. In this speech, Kennedy boldly declares the nation's commitment to achieving the goal of landing a man on the moon and returning him safely to Earth before the end of the decade. This speech is considered a pivotal moment in American history and a defining moment of the Space Race.<end_of_turn>

# %% [markdown]
# # Let's combine all 3 modalities together!

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "audio", "audio": audio_file},
            {"type": "image", "image": sloth_link},
            {
                "type": "text",
                "text": "What is this audio and image about? " "How are they related?",
            },
        ],
    }
]
do_gemma_3n_inference(messages, max_new_tokens=256)
# Out:
# The audio is a famous excerpt from President John F. Kennedy's inaugural address in 1961. In this speech, he passionately calls on the nation to commit to a goal of landing a man on the moon and returning him safely to Earth before the end of the decade.
#
# The image shows a sloth hanging upside down from a tree branch in a lush, green environment.
#
# **How they are related:**
#
# The connection between the audio and the image is **metaphorical and likely intended to convey the slowness and deliberate nature of the space race.**
#
# The phrase "landing a man on the moon" represents a monumental and ambitious goal, while the sloth, known for its incredibly slow movement, serves as a humorous contrast.
#
# The image likely aims to playfully suggest that even with the urgency of the space race, there's a certain inherent slowness or patience required to achieve such a grand ambition. It's a lighthearted way to juxtapose the extraordinary goal with something very ordinary and slow-moving.
#
# It's not a direct literal connection, but rather a clever visual metaphor playing on the contrast between human ambition and natural processes.<end_of_turn>

# %% [markdown]
# # Let's finetune Gemma 3N!
#
# You can finetune the vision and text parts for now through selection - the audio part can also be finetuned - we're working to make it selectable as well!

# %% [markdown]
# We now add LoRA adapters so we only need to update a small amount of parameters!

# %%
model = FastModel.get_peft_model(
    model,
    finetune_vision_layers=False,  # Turn off for just text!
    finetune_language_layers=True,  # Should leave on!
    finetune_attention_modules=True,  # Attention good for GRPO
    finetune_mlp_modules=True,  # SHould leave on always!
    r=8,  # Larger = higher accuracy, but might overfit
    lora_alpha=8,  # Recommended alpha == r at least
    lora_dropout=0,
    bias="none",
    random_state=3407,
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Gemma-3` format for conversation style finetunes. We use [Maxime Labonne's FineTome-100k](https://huggingface.co/datasets/mlabonne/FineTome-100k) dataset in ShareGPT style. Gemma-3 renders multi turn conversations like below:
#
# ```
# <bos><start_of_turn>user
# Hello!<end_of_turn>
# <start_of_turn>model
# Hey there!<end_of_turn>
# ```
#
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, phi3, llama3, phi4, qwen2.5, gemma3` and more.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template="gemma-3",
)

# %% [markdown]
# We get the first 3000 rows of the dataset

# %%
from datasets import load_dataset

dataset = load_dataset("mlabonne/FineTome-100k", split="train[:3000]")
# Out:
# README.md:   0%|          | 0.00/982 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/117M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/100000 [00:00<?, ? examples/s]

# %% [markdown]
# We now use `standardize_data_formats` to try converting datasets to the correct format for finetuning purposes!

# %%
from unsloth.chat_templates import standardize_data_formats

dataset = standardize_data_formats(dataset)
# Out:
# Unsloth: Standardizing formats (num_proc=2):   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
import json

# Read JSON from file
with open(
    "/home/tyler/python/agents/raw_video_transcripts/penguin/data.json", "r"
) as file:
    data = json.load(file)
data
# Out:
# [{'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'A text thread was received from Matt in the morning, considered to be particularly noteworthy and appealing.',
#   'output': "Here's something I haven't done in a long, long time \n A text thread \n This puppy is something Matt sent me this morning and it's special \n It is irresistible"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "A user had been interacting with a potential match on the dating application Hinge for approximately two weeks. They had met in person on a few occasions; however, the user did not find the individual's company particularly enjoyable.",
#   'output': " I have to app about it \n A guy had been seeing a girly match with on Hinge for like two weeks \n They'd only hung out a couple of times \n But he wasn't really enjoying her company all that much"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'He chose to formally submit his resignation notice rather than abruptly ending the relationship. The communication was presented as a formal resignation, acknowledging past positive experiences while indicating the need to pursue separate paths. This action resulted in a significant reaction. The message was considered to be delivered in a relatively respectful manner.',
#   'output': " And instead of just ghosting her and disappearing, decided to just rip the bandaid off and put in his two weeks notice \n You know, like I'm resigning from this, we had some good times, but you know, we need to go our separate ways into the sunset here \n And all hell broke loose \n It was a pretty respectable message"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Alignment discrepancies were identified that are significant to one party. The decision was made to communicate these concerns openly rather than proceeding under the assumption of compatibility, aiming for clarity and directness without intent to offend.',
#   'output': " Hey, I'm realizing we're not aligned in ways that matter to me \n I'd rather be honest now than keep moving forward when I don't see it working out long term \n Very concise to the point \n It's not rude"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The event had a significant impact similar to that of the asteroid responsible for the extinction of the dinosaurs.',
#   'output': " Very simple \n And man, that hit like the meteor to the dinosaurs here \n Oh, well, okay \n I hope you find what you're looking for, I guess"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'An individual expressed disappointment after realizing that their feelings were not reciprocated by another person, leading to sadness.',
#   'output': " Me thinking I found my person and you don't even feel the same \n LMAO \n You just says same to you \n Now I'm sad"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "The individual expresses interest in discussing conspiracy theories and having children, comparing their passion for conspiracies to Garfield's fondness for lasagna.",
#   'output': ' Block me \n All because I want to tell you conspiracies and I want kids \n Now you know me \n I love conspiracies like Garfield loves lasagna'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'This individual exhibits an obsessive interest in conspiracy theories and incorporates them significantly into her daily life.',
#   'output': " But there comes a point where it's just overwhelming \n This individual here, she's not just wanting to tell him conspiracies \n She is obsessed with conspiracies \n She lives in breeds"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Conspiracy theories are frequently discussed and shared widely online, sometimes in large volumes. Individuals may engage in detailed explanations or discussions regarding these theories, occasionally presenting them in an elaborate or dramatic manner.',
#   'output': " In conspiracies out the wazoo \n You're about to see just like a flood of unhinged like Lord dumping \n She starts trying to give this guy a homework on conspiracies \n She then gets into anime monologue territory"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Five days have passed, and people, life, and circumstances undergo变化。但战争始终不变。 \n\nNote: The last part "But war, war never changes" is kept in English as it appears to be a reference or quote that doesn\'t need further contextual translation for the message to remain clear. If a full Chinese translation is preferred, it would be "但战争，战争从未改变".',
#   'output': " It's also been five days and people change \n Life changes \n Circumstances change \n But war, war never changes"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Once an individual reaches a specific age, their height remains constant.',
#   'output': " And you know what else doesn't change? Once you reach a certain age, that is your height \n Doesn't that damn I actually felt something with you which isn't something that happens often \n But you know what? You want from your person, I guess \n I don't know why I'm reading this like AI"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The morning marks the beginning of a period when activities such as conflict may occur.',
#   'output': " It's first thing in the morning \n Now we can actually fight \n Thank God \n It's about time"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The statement includes an expression of capability to engage in conflict, followed by an exclamation of enthusiasm, an observation about the peculiarity of a referenced action, and a reflection on receiving an unspecified consequence due to having a preference for a particular political ideology.',
#   'output': " We can actually fight \n Woo! Yeah \n What a weird thing to throw in there \n That's what I get for liking a lib"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'There is an assertion that men perceive multiple choices in relationships when, in fact, only one choice is presented as valid.',
#   'output': " I'm upset because what the fuck fix your feelings \n I don't care \n Men and their illusion of options \n Yes, you see there's only one option and it's her"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The phrase "All roads lead back to this angel" was stated. The speaker mentioned having a tendency to speak without substantial basis regarding conspiracy theories. There was an initial belief of falling in love upon a visit, but it was noted that the other party did not desire their presence.',
#   'output': " All roads lead back to this angel \n I told you at dinner, I like to talk out my ass when it comes to conspiracies \n I thought I fell in love with you when I came over in the entire time \n You didn't even want me there"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Delusional beliefs can occur rapidly and this phenomenon can be concerning.',
#   'output': " That's delusion and that's okay \n God \n That's like just scary \n The fixation like how quickly that can happen"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual expressed that they believed falling in love occurred after interacting a limited number of times over a two-week period. The author also stated they intend to refrain from dating for several months. Reference to "weak pictures" was made, though the context is unclear.',
#   'output': ' I thought I fell in love with you when they only hung out like a handful of times over the course of two weeks \n Thank you for your time, Elameo \n I am again done dating for a few months \n Our weak pictures'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The image resembles the interior of a dishwasher.',
#   'output': " I can't quite make out what that's supposed to be \n It looks like the inside of a dishwasher \n I don't know if they shrunk themselves down on Miss Frizzle's school buzz or something and took an adventure inside of a dishwasher \n But that's what it looks like to me"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She sent pictures to commemorate their time together. The individual expressed dissatisfaction with dyeing their hair pink as requested and mentioned considering removing the character from a video game. This action is considered a significant warning sign in relationships.',
#   'output': " I'm not really sure \n But she sends like some pictures to commemorate the great times they had together \n Now I have to take down and restart my hair because why am I literally doing it pink like you wanted? I have to kill you on Sims \n That's one of those big red flags right there"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'In the context of the game The Sims, a character created within the game was marked for virtual elimination. This scenario reflects themes involving psychological distress and cruelty, symbolized through the analogy of depriving a living entity of its ability to thrive.',
#   'output': " There's a lot to unpack with just that one line \n Now I have to kill you on Sims \n That's that psychoshit like ripping the wings off a butterfly \n First of all, she made him in Sims"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual planned their lives together through the game Sims to assess readiness for a relationship. Following the deterioration of their relationship, they intend to virtually end the character representing the other person within the game.',
#   'output': " After I guess she was like planning their lives together through Sims to see if it's something that she you know is ready to you know get ripping and roaring on \n And now that it's gone south, she's going to have to execute and murder him on the Sims \n I imagine there will be torture involved too \n Just a hunch"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'A person who has an interest in another individual may be perceived as unusual or unexpected by the latter. An agreement to meet on a specific day was made. Affection or positive feelings exist despite previous circumstances or expectations.',
#   'output': " Just a hunch \n A girl that actually likes you is too much Elameo \n Anyways, I'll see you Saturday \n I love that after all this"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual will be seen on Saturday.',
#   'output': " It's like okay, so now that you're done being stupid about this whole like we don't align type of thing \n I'm going to see you on Saturday, isn't that right? I will see you Saturday \n Don't you forget it \n I will see you Saturday"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The character was eliminated in a game of The Sims. Plans for a meeting on Saturday remain unchanged. There is a belief that a strong connection exists between the individuals, suggesting they are destined to be together.',
#   'output': " Yes, I killed you on the Sims, but I had to do what I had to do \n It doesn't mean I don't want to see you on Saturday \n We're still so much \n We're meant to be together"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The statement conveys a sense of acknowledged mutual affection and an assertion of inevitability regarding recognition of that affection.',
#   'output': " You know that \n I like you \n You know that \n And you don't have a choice"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The phrase describes a situation where there appears to be a choice or option, but this is misleading. On the first absence, an individual found companionship, not because someone was "taken," but due to mutual attraction and recognition.',
#   'output': " It's an illusion of options \n First day you didn't see me in a row and I got my man taken \n I mean, man didn't get taken \n Man just came to his senses"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'He did not disappear suddenly without notice and was open about the situation.',
#   'output': " This is all very concerning stuff \n It's like it is what it is \n He was up front with you about it \n He didn't ghost you"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The response indicates that the current situation may not be an appropriate match. There is a sentiment of disappointment regarding previous communication and a declaration of loyalty. No specific disagreements are identified.',
#   'output': " And man, I got to tell you, I think overall this response to it is showing that maybe this just wasn't the right fit \n Telling me to keep you just for you to leave \n I'm sorry for blowing you up, but I'm just a deeply loyal person \n I don't see what we don't agree on"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Disagreements exist among humans due to varying lifestyles and experiences. A screenshot was provided from another conversation involving discussions about the Mossad and the CIA, though its relevance to the current context is unclear.',
#   'output': " And even when, and even then, why do we have to agree on everything? We're human with our own lifestyles and experiences \n I'm so sad \n While I'm sensitive and bleeding isn't nice, could have waited two days when I'm back to being myself \n And then she puts a screenshot from another match she had on hinge, where she's talking about the Mossad and the CIA, which I'm not really sure what that has to do with what's going on here, but she does provide it regardless"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'In some relationships, one partner may send a single message indicating that the relationship is not working, while the other partner might respond with numerous messages over a prolonged period, such as forty-five messages in an hour and a half.',
#   'output': " I guess as like some parting ways reading to brush up if you want the real \n This is why I hate liberal men because why are you more sensitive than me? Well, I think him sending one message about like, hey, it's not working out \n I don't really love us together \n And then you having 45 messages over the course of like an hour and a half"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'No notable sensitivity was observed.\nThe assertion appears to be an unusual projection.\nThis conclusion seems somewhat speculative.\nA period of one day for reflection was offered.',
#   'output': " It doesn't seem like he's more sensitive at all \n Actually, that's kind of a weird projection, to be honest \n That's a bit of a reach \n I'll give you one more, I'll give you one day of space"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual will be present the following day.  \nShe plans to closely observe him from a distance.  \nIndifference is expressed towards the situation.  \nThere is an assertion of mutual exclusivity in association.',
#   'output': " I'll see you tomorrow, caps locked \n She's going to be in like a fucking tree with binoculars looking at him, spying or something, smiley face \n Yeah, I don't care \n You're either with me or we're together"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'There are two options regarding the individual: kidnapping or another action.',
#   'output': ' Those are your only two options \n Oh, fuck \n About the kidnap them or something \n It reminds me of that hat'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "The individual consumes 14 beers in a social setting. The person has an attractive, intelligent sense of humor that responds well to jests. They possess good communication skills. There is an appreciation for the person's physical attributes and their unique, nerdy personality traits.",
#   'output': " You're either drinking 14 beers with me or you're drinking 14 beers against me \n Your cute smart laugh at all my jokes \n Easy to talk to \n I like your hands and your arms and your weird nerdiness"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual expressed that they had tasks to complete and briefly acknowledged the passage of time before departing with well wishes.',
#   'output': ' Okay, I have shit to do, but still count your days \n Literally one, but yeah \n Okay, bye \n Have a good day'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She posted additional screenshots focusing on Jewish traditions and Jewish banking, turning her tweets into a comprehensive Twitter thread over the span of two minutes.',
#   'output': " And then she drops some more screenshots here \n This one's about Jewish tradition and Jewish banking \n So it's becoming a full blown Twitter thread here \n And it starts sending these all of this over the course of two minutes"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The data is stored on her手机。我想一直为你做饭并永远爱你。阻止你的祝福。 \n\nNote: The last part "Blocking your blessings" doesn\'t have a clear factual statement equivalent, and the phrase "so fucking hilarious" was omitted as it does not convey any fact. Also, the sentence about cooking and loving forever is kept as it stands but note that such personal expressions do not typically appear in Wikipedia articles which focus on objective facts.',
#   'output': " So it's all saved to her phone \n And I'm actually so fucking hilarious \n And I wanted to cook for you and love you forever \n Blocking your blessings"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'A maculid head was given. Further consideration suggested that the action may have been executed hastily.',
#   'output': ' And I gave a maculid head \n Shit, wait, wait a minute \n Hold on, hold on \n He may have been too hasty here'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The possibility for a reevaluation of the relationship exists. Previous communications, totaling 66 messages, are no longer considered relevant.',
#   'output': " That ought to make him rethink everything \n We can now disregard the previous 66 messages that have come through here \n And maybe we can at least reevaluate this relationship \n That's quite the Hail Mary"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual is a beneficiary of a trust fund and receives VA benefits due to their parents being retired on 100% disability. Further details regarding international sections are unspecified.',
#   'output': " And I'm a trust fund kid with VA benefits because both my parents are retired and on 100% disability \n Law, okay, I'm done now \n Your loss for sure \n What? Internation? What kind of? What? I don't even know what to say about that section there"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Individuals may engage in social interactions with others who lack particular desirable qualities. The term "OTP" is used to denote a couple or pairing that an individual considers their preferred or ideal match. In the context of the video game League of Legends, "OTP" does not have a specific recognized meaning related to the game\'s mechanics or features. The phrase "one trick pony" refers to someone or something with only one notable ability or quality.',
#   'output': " I have fun with bitches that don't like you and that aren't funny or pretty or won't want to do anything for you \n I was OTP with my best friend \n I don't know what OTP stands for in League of Legends \n That's one trick pony, but that doesn't really fit here"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual expressed their feelings towards another person to their best friend, following a message received from that person. They acknowledge they will not meet in person again and wish the other person well on an upcoming date.',
#   'output': " But whatever \n I was OTP with my best friend literally telling her how much I liked you when you sent that message because what the fuck? But I know we're never going to see each other again \n So it's all a good friend \n I hope your date does"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "The individual expresses conflicting sentiments regarding another person's physical appearance and ideological preferences, alongside a mention of experiencing intense emotions rapidly.",
#   'output': " I hope your date goes well \n Actually, I hope she's ugly \n And loves the white savior complex \n I can't feelings way too fast"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "The individual acknowledges their mistake, expresses relief over another's sense of security, indicates approval of a positive situation, and suggests that prior notification would have been beneficial.",
#   'output': " My fault for sure \n I'm glad you feel safe \n That's good \n You could have warned me"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual will continue their actions until they feel an improvement in their state and does not require responses from others, expressing a sense of defeat.',
#   'output': " Literally if you haven't blocked me, I don't know \n I'm gonna keep going until I feel better \n I don't need to respond to anything \n I feel really defeated"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual decided to commit to the option available, emphasizing the importance of having alternative options for relationship choices.',
#   'output': ' But it could really just be me on my period \n I was so ready to lock in \n Actually, I did \n See, this is why you always have multiple men'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual expressed a desire for a singular partner rather than multiple, and an aspiration to live as a stay-at-home mother in a woodland area where they would maintain both a garden and operate a bakery. However, the current situation does not align with having only one partner.',
#   'output': " But I didn't want multiple \n I wanted one \n I want to be a stay-at-home mom in the woods with a garden in my bakery \n But you don't have just one man"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'A screenshot was sent approximately ten minutes ago, depicting a conversation with another individual on Hinge about Masad. This indicates engagement with multiple individuals on the platform. The preference for living in the city without children and maintaining an equal partnership was expressed.',
#   'output': ' You just sent a screenshot like 10 minutes ago of you talking to another guy on Hinge about Masad \n Like, what do you mean? You definitely are talking to multiple men \n But I guess this was her favorite \n You want to live in the city with no kids and be 50-50 with whomever'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual in question had previously engaged in deceptive behavior with a former partner. The speaker did not desire such actions to be taken.',
#   'output': " So I get that \n But the last bitch you were with, you tricked, you tricked for \n And I didn't even want that \n What does that mean? You tricked for"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The actions taken were unclear. The individuals involved reportedly have differing preferences. The separation is described as amicable.',
#   'output': " I'm not familiar \n Like, what do you do? Hit it like a kickflip or something to impress her? I'm not positive \n But like, even she's confirming that they want like different things \n Like, it should be like a really amicable split here"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The relationship is described as a split; however, the individuals are not in a dating relationship. They have minimal knowledge of each other and interact at a level slightly more familiar than that between strangers. No significant mutual contributions were made.',
#   'output': " And I'm calling it a split, but they're not dating \n They hardly know each other \n They're just like a step above strangers \n Didn't even give you anything"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'A partnership was desired, but the intentions of the other party were unclear.',
#   'output': " Or maybe you lied \n I wanted a partnership \n And you want, I don't even know actually \n It's okay"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Mario is one of the most recognizable properties in popular culture.',
#   'output': " I'm too pretty to be doing this \n Have a good day, especially when we have everything in common \n Do you have any friends that like Mario and being in love? Mario's like one of the most well-known property of all time \n I bet he has tons of friends like Mario"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "Love is considered a fundamental human desire experienced by the majority of the world's population. There is no specific information available regarding an individual's friendship circles or their interests in Mario or conspiracy theories. Conspiracy theories can be entertaining for some individuals.",
#   'output': " And as far as being in love goes, it's like a basic human desire that 99% of the world also feels and wants \n So yeah, I would say, I don't know this guy, but I would say with high confidence, he probably has a lot of friends that like Mario and being in love, just a hunch \n And like obsessive conspiracy theorists \n Yeah, see like conspiracy theory and yapping about it's like really entertaining and enjoyable"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "When the preoccupation with an activity evolves into an obsession, such that it dominates one's thoughts and conversations, the initial enjoyment may diminish. This transformation is generally considered unfavorable.",
#   'output': " But when it becomes a full-blown obsession, where it's like all you think about and all you talk about, it's no longer fun anymore \n So like that's not a good thing \n That's a negative \n I do need a response actually"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The message indicates that the sender is questioning why there has been no action taken to prevent further communication, suggesting termination of contact and implying that engagement with less demanding individuals would be preferable. The message concludes with an offensive statement.',
#   'output': " You haven't blocked me \n Why are you letting me still text you? Close the door and move forward with someone mediocre \n That's more your speed \n I'm just gonna say you have a shrimp dick and move on"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'They reached a point where they feel better about the situation.',
#   'output': " I feel better now \n Well, that's good \n I'm happy to hear that \n I'm glad they were both able to reach a point where they feel better about all of this"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She returned a few hours later and apologized, explaining that she was not accustomed to meeting Goodman and had attempted to discourage contact due to skepticism. She acknowledged the mistake and requested another opportunity, expressing willingness to maintain a neutral relationship if necessary.',
#   'output': " And then she comes back a few hours later \n Hey, I just wanted to apologize \n I'm not used to meeting Goodman, so I thought it was too good to be true, so I tried to scare you off \n I realize I messed up and if it's okay with you, I want another chance, even if we're just cool for now"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'According to the post, the individual did not block the other person following an apology. It appears that they will likely not interact with each other frequently in the future.',
#   'output': " If not, it's okay too \n You're an amazing man, honestly \n I know that's quite a cliffhanger to be left on, but according to the guy who posted this, he didn't end up blocking her after that apology \n So it's seeming like they're not going to be seeing too much of each other anymore"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'They do not appear to be highly compatible. She may find another individual with whom she can exchange conspiracy theories. The current era provides ample opportunity for such connections. Through social media platforms like Twitter, she could potentially connect with a large number of people who share similar interests.',
#   'output': " Probably for the best, they don't seem super compatible \n I am sure she will find someone that she can spit conspiracy theories back and forth on \n Now is the perfect day in age for that \n She could probably find 10,000 men through Twitter right now that would absolutely love her"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'This choice was inappropriate. They were incompatible as a pair. More than one hundred messages are unnecessary when there is limited familiarity between individuals who have met infrequently and the connection lacks depth.',
#   'output': " This just wasn't, you know, the right choice here \n They weren't meant for each other and that's okay \n I don't think you need over 100 messages when A, you don't even know the person very well \n You've only seen them like a couple of times and B, it's just not that deep"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'There is no substantial content to report.',
#   'output': " It's just, it's seriously just not that deep \n Anyway, though, that's really about it \n See ya \n"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "A video has surfaced showing a woman operating a Turo-rented vehicle who was involved in an accident. The video, allegedly posted by the vehicle's owner, suggests that the individual attempted to misrepresent the events following the incident.",
#   'output': 'Are you mad right now? Do you want to be? I saw a video today that was pretty infuriating \n This lady is behind the wheel of a rented vehicle from Turo \n This is allegedly posted by the owner of that vehicle after spoiler alert \n She gets into an accident here and then tries to lie about what happened'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The post was made to illustrate the actual events. Observers noted that the individual was texting while driving, with a greater emphasis on texting than on driving. The primary focus appeared to be on composing text messages during the journey, possibly related to an argument.',
#   'output': " This was posted in response to that to show what actually happened and if you've got some keen peepers on you, the astute observers may have noticed she's texting while driving \n But to be honest, I don't even think that's accurate to say because she is doing more texting than driving \n So she's like occasionally splicing in some driving between her texts \n It seems like she's in some kind of heated argument and that is like her primary focus is sitting these text messages while on the road"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Texting while driving poses significant risks to road safety. This behavior is widely recognized as dangerous, with numerous incidents highlighting its severe consequences.',
#   'output': " I'm sure I don't need to educate you on the dangers of texting while driving \n I'm not the DMV \n I'm also not your dad \n I imagine most of you know that and this is one of the most egregious examples of texting while driving I've ever seen"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She chose to send messages while driving rather than pulling over, despite the risks to herself and others. The content of her messages was considered by her to be of high priority.',
#   'output': " She could easily have just pulled over and sent those messages if it's that urgent \n But instead she said, fuck it, we'll do it live so she's doing it while on the road risking her life and the life of those around her \n I guess she's really got places to be in those messages that's like fucking utmost importance \n If you're not first your last, if you're not pooping your shit"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She held onto her phone throughout the incident where her vehicle veered off the road and collided with a mailbox.',
#   'output': ' Even while her car is veering off the road and blasting a mailbox, she is firmly grasping that phone \n She is gripping the shit out of that \n She still will not set it down in the act of crashing this vehicle \n She treated that phone like it was the fucking tesseract there'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She does not relinquish possession of it. Only when its operation ceases does she place the device down, subsequently placing her head in her hands, before picking up the device again within three seconds. The object is inseparable from her. It serves as a vital connection for her.',
#   'output': " She was not parting with it \n It's not until it is finally stopped that she sets the phone down and then puts her head in her hands and then immediately picks the phone back up after like three seconds \n She can't be separated from it \n It's her fucking umbilical cord"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She looked up from her phone only five times during her duration in the single lane, which increased the risk of a head-on collision.',
#   'output': " It's unreal \n It's actually a miracle she didn't just have a head-on collision here \n I counted too \n She looked up from her phone only five times in the amount of time that she spent on that single lane there"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She spent most of her time driving while using her手机。在某个时刻，她甚至双手持手机以获得更好的操作。她的行为导致没有手放在方向盘上，也没有抬头看路。这种行为极大地增加了发生事故的风险。',
#   'output': " So she spent the vast majority of her time there behind the wheel looking at the phone glued to it \n In fact, she even double fisted the phone at one point to get two thumb action in there \n No hands on the wheel, not looking up at the road \n It is actually an act of God that she didn't kill herself or somebody else there"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The vehicle could have potentially collided head-on with another car had the driver steered left instead of right, which may have resulted in serious injuries or fatalities. Following the incident, the driver emitted high-pitched screams and an intense vocal outburst characteristic of frustration, despite being at fault for the incident.',
#   'output': " Just an unsuspecting innocent car that she could have easily veered to the left instead of the right and just hit with a head-on collision which would have potentially been fatal \n Also, her squeals that she lets out, oh man, that is ear piercing \n And then she has like that full blown like angry middle-aged mom scream after it like comes to a stop \n Even it's entirely her fault"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual involved is a nurse practitioner who provided false information to the Turo vehicle owner regarding the circumstances of the crash. Video evidence indicates the individual was frequently texting while operating the vehicle at the time of the incident, suggesting this may not be an isolated occurrence.',
#   'output': " Apparently again, the story is she's like a nurse practitioner and lied to the Turo owner here of this vehicle about what happened and why the car got crashed \n I haven't seen too many details on all of that, but it's entirely her fault \n She, you can see here in the footage, she is texting the vast majority of the time that she spins on the road \n And I imagine this isn't an isolated incident"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Texting while driving has been identified as a dangerous practice. Despite widespread awareness campaigns highlighting its risks, instances of individuals engaging in this behavior persist. There is anecdotal evidence suggesting that such behaviors may be increasing, including examples of streaming content creators who have been observed text messaging and reading messages from viewers while operating a vehicle.',
#   'output': " This is probably how she goes about her daily commutes \n You can tell people to the cows come home how dangerous and bad it is to text and drive, but then you're still going to have people like this doing it \n And it's actually, to me, it seems like becoming more common \n Like I know there was like even a trend a little while ago for streamers to do like car streams and in some of them, they were just texting and reading the chat while driving"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'People often fail to comprehend the significance of avoiding distracted driving. An example of extreme distraction while driving has been captured on film.',
#   'output': " Like while being filmed doing it \n So it seems like people don't really grasp how important it is to not drive distracted \n But anyway, this is probably the most egregious example of it that I've seen \n This is unhinged"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'She was deeply focused on her手机，以至于忽略了她正在操作机动车辆的事实。这种情况可能导致她未能优先考虑周围人和她自己的安全。关于此事件的结果信息不详。 \n\n(Note: The last sentence was translated directly, which resulted in a mention of "手机" (mobile phone) and "机动车辆" (motor vehicle). If you prefer the entire response to be in English, please let me know.)',
#   'output': " It's like she totally forgot she was operating a motor vehicle \n She was so engrossed in her phone \n That took priority over everyone's lives around her and her own life \n Now I don't know what the outcome of all of this was"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual in question is identified as a nurse practitioner and there are claims that she provided false information regarding the circumstances of a vehicular accident. The vehicle owner had installed both an interior-facing dashboard camera and another dashboard camera. There was discussion about the legality of having an interior-facing dashboard camera in a rented vehicle.',
#   'output': " There's not a ton of information I can find on it other than like she's apparently a nurse practitioner and apparently lied about how the car got crashed \n But the owner of the vehicle had the interior facing dash cam as well as the other dash cam \n People were debating if that's even legal to have like a rented car with an interior facing dash cam \n I looked it up"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Disclosure of the item to the renter is typically included in the signed contract between双方签订的合同中通常会包括向租户披露该物品的条款。我对Toro不甚了解，也没有使用过它。为了保持一致性并完全基于给出的信息，此处直接翻译了处理后的中文内容，但原始指示要求仅陈述事实且没有提及特定未熟悉产品的需要，因此关于"Toro"的部分在正式的事实性陈述中应予以省略，只保留关于合同披露的相关客观信息。',
#   'output': " It is \n But you just need to disclose to the renter that it's there which I imagine is part of like the signed contract between them or something \n I've never used Toro \n I'm not super familiar with it"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'In cases where a rented vehicle is damaged, owners may implement measures to secure evidence of the condition of the vehicle before and after rental to protect against unfounded claims by renters. This can provide necessary evidence should disputes arise over the cause of any damage.',
#   'output': " But it seems like the owner is well within the right to do that \n And I could definitely see why people that are renting their car out might want that as like a bit of a security measure here \n As this case beautifully illustrates where your car gets wrecked and then all of a sudden the person I was driving it starts farting out a fairy tale about how it's not there fault and then you've got no evidence that it was there fault \n So now you're stuck with your dick in your hand and you're going to have to pay for that most likely"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The action likely prevented significant complications, allowing immediate attribution of the issue solely to the individual responsible.',
#   'output': ' So I can see why you would want that there \n And in this case it probably saved them a huge headache because they can instantly point to this as her fault because it is her fault entirely her fault \n Anyway though enough blabbering about it for me today \n A little PSA for you'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Texting while driving is discouraged due to safety risks.',
#   'output': " Don't text and drive \n That's really about it \n See ya \n"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Method acting involves actors immersing themselves in their characters\' traits and behaviors. In this instance, the actor is portraying a character described as a "slimy, greasy caveman."',
#   'output': "You think I'm unshoured and greasy, don't you? You should be ashamed of yourself, that's pathetic \n This is called acting \n I am simply playing a character that is a slimy, greasy caveman \n It's method acting"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'A Charizard Pokémon card was stolen from a booth at a card show. The incident was captured on 4K video. The video will provide a detailed account of the theft.',
#   'output': " You swine \n You wouldn't know anything of it, would you? With your ignorance out of the way in this myth fully busted and debunked, I'd like to proceed with the video topic if you don't mind, which is of course more Pokemon card thieves \n I literally caught somebody in 4k, stealing a charizard from my booth at a card show \n So let's do a play by play"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The card in question commemorates the 25th anniversary of Charizard. It is frequently reported as stolen.',
#   'output': " The card in question is a 25th anniversary celebrations charizard \n But let's start out by actually locating the card \n I don't even know how many videos I have at this point covering Pokemon card thieves \n This has to be one of the most commonly stolen items"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Items such as smartphones are frequently secured with locks and encryption, making them difficult to utilize if stolen. As a result, the utility of stealing a smartphone, beyond its physical components, is limited for unauthorized individuals.',
#   'output': " Like what else would even be close? Fones? Maybe? Like perhaps? But I don't even know, because phones, like nowadays, are like often locked down \n And people know that if you just steal a display phone, you can't do shit with it \n You can maybe shove it up your ass and that's about it \n So like I can't even think of something else that would be stolen"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Pokemon cards have been frequently stolen, with at least five to six reported robberies per week supported by video evidence. Video footage also exists showing an individual at an event picking up one of the cards, specifically a Charizard card, from a table.',
#   'output': " That would be stolen as frequently as Pokemon cards have been over the last year \n Because there's at least like five or six robberies a week that we know of with video evidence of people stealing Pokemon cards \n And here we can see one of the guys at the show pick it up to have a look at it \n We can see put the charizard card right down at the front of my table"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "Jamie is observed walking past a Charizard card, making direct eye contact with it. The individual's attempt at remaining inconspicuous is hindered by their facial tattoo and high-visibility clothing.",
#   'output': " It's in the danger zone \n And now moments later, let me introduce you to Jamie \n Now between the face tat and the high viz, Pro's not helping himself go incognito on this one \n We see Jamie walk past the charizard card and quite clearly lock eyes with it"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Comments included speculation about whether the first individual was involved in an undisclosed situation. It was noted as unusual for him to move the Charizard card away from its original location, particularly at an event where attendees typically possess knowledge about cards. Placing a valuable card on the edge of a table could be interpreted as drawing attention to it in a manner similar to attracting notice in a competitive environment.',
#   'output': " I saw a lot of super sleuths in the comments, debating whether or not that first guy was in on this \n And I will admit, it is odd that he would pick up the charizard and then put it so far away from the place that he got it from \n And especially at a card show, most people there probably are somewhat knowledgeable on cards \n He would definitely know that putting a card on the edge of the table there, that's like showing the waters around sharks"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "The situation has the potential for disaster. There is a suggestion that prior knowledge existed between the individuals involved, implying a premeditated event. However, the uploader, who personally knows one of the individuals, claims the encounter was unrelated to any such plan, stating the individual's interest was in purchasing a card.",
#   'output': ' That is a disaster waiting to happen \n Like I feel like there is merit to the idea that he could have known this guy \n And this was like a planned thing \n But the uploader shoots that theory down by mentioning that he actually knows that first guy personally and he was interested in buying that card'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'He stepped away to attend to an external matter. Subsequently, they departed to address this issue before returning to purchase the card, which was no longer available. He also stated that the two parties should never have any contact.',
#   'output': ' The reason he had to step away was because something outside of that needed his tending to \n So we left to go do that and then came back to buy the card \n And it was gone \n And he said at no point to those two ever interact or anything'},
# ...
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Underlying medical conditions may deteriorate when subjected to torture. Individuals experiencing torture, even if not resulting in immediate death, still suffer adverse health impacts. The actions of those inflicting such conditions cannot be considered without moral or ethical repercussions. Death did not occur as a direct result of the trauma experienced.',
#   'output': " I think if someone has underlying medical conditions, fundamentally torturing them is probably just going to make it worse \n Even if the torture doesn't directly kill them, I would be shocked if anyone thinks that this means that those streamers hands are clean like up \n Case closed \n He didn't die from any of the trauma he experienced"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'He sustained multiple bruises and exhibited signs of长期虐待和折磨。然而，他的死亡被确定为自然原因所致，与所遭受的虐待无直接关联。这些个体的行为被认为是偶然发生的，不应承担责任，他们被视为道德无暇的人。',
#   'output': " Yeah, he had some bruises and all that and yes, he was abused for so, so, so long mistreated and fundamentally tortured by these individuals, but his actual death, well, it looks like that was just of natural causes and had nothing to do with any of this innumerable amount of torture that we've bore witness to \n Surely that was all just circumstantial, had nothing to do with any of that \n They're blameless \n These are just some, some saints here"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "Raphael Graben's associates will likely mourn his death. The cause of death was attributed to medical issues unrelated to any abuse he may have experienced over a prolonged period at the hands of certain individuals.",
#   'output': ' These are angels actually \n These are just good friends of Raphael Graben who are clearly going to be mourning his loss just as much as everyone else \n They did nothing wrong \n It was just, it was just medical problems that in no way was impacted by the abuse that he was subjected to for such an extended period of time from these individuals'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Numerous clips depict instances of severe physical abuse towards the individual, which likely contributed negatively to his overall health. Text messages from Raphael Graben to his mother suggest he experienced significant stress and felt unable to leave the situation. There are also recordings where the abusers discuss having the victim acknowledge that any fatal consequences would not be their responsibility.',
#   'output': " I think all of the evidence that you can freely watch of all of the numerous like unfathomable mountain of clips of them just beating the shit out of him and literally like like abusing him constantly, fundamentally torturing this man would indicate that they definitely played a role in making his overall health worse \n And we have the text messages from Raphael Graben to his mother that indicate how much stress he was under and how he felt like he was being held hostage by them that he couldn't leave and that he desperately wanted out \n It was so bad with their abuse of this man that they actually had him on stream confirm that if he dies, it's not their fault \n I had to translate this, but in a clip that's out there, they are saying, well, what happens if John Parmanov dies? They said, well, we're going to have to get him to say that it's not our fault if he dies"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The cause of his death, should it occur, has been attributed to a combination of lifelong poor health, unwise decisions, and an unhealthy lifestyle. He initially refused to acknowledge these factors but was compelled to do so. There is an assertion that external parties forced him to claim his potential demise would not be due to the mistreatment he endured. This compulsion highlights awareness of his vulnerable state by those parties.',
#   'output': " It's a result of his lifelong bad health, his bad decisions, his terrible way of living that led to his death if he dies \n And he initially said, no, he didn't want to say that, but they made him say that \n They forced him to say that if he dies, it is not because of all of the abuse that they subject him to \n Does that sound like the actions of an innocent party here? They knew that he was vulnerable"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "They were aware that their actions could result in the individual's death. They attempted to mitigate liability by having the individual sign a document stating that any death would be due to pre-existing health conditions, despite initial refusal from the individual who was eventually persuaded. The individuals subjected John Parmanov to prolonged abuse over several months prior to his death. There is contention regarding whether this extended period of abuse contributed to his passing.",
#   'output': " They knew that what they were doing could very well end up with him dead, it seems \n And then to try and cover their ass, they had him agree that if he dies, it's because of his own health problems, which he initially declined to do, but they kept insisting that he he clears them \n Like, it's fucking absurd to try and make the claim that all of these streams, the months worth of abuse, more than months, a long time of abuse they subjected John Parmanov to had no role to play in his passing \n It's craziness to try and make it seem like just because they didn't like fucking kill him on the spot on stream that they had nothing to do with his death"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "Some individuals have suggested that an individual's voluntary agreement absolves others of any wrongdoing. However, evidence from text messages indicates that the individual did not consent and felt compelled to remain against their will, suggesting a situation akin to detention.",
#   'output': " Now, something I've seen popping up from some real fucking brain dead morons here, huffing stupid juice is that, well, he agreed to all of it so it's his fault, can't be mad at the streamers \n If that isn't the biggest load of fucking barnacles I've ever heard, first of all, we know from the text messages, he didn't want to do it \n He wanted to leave, but felt he couldn't leave that he was being held hostage there \n They weren't letting him leave"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The text message sent to his mother gave an impression. There are claims that he was sometimes financially pressured to participate. It appears that a mentally vulnerable individual seeking friendship was manipulated to be part of a scheme where abuse was inflicted for the purpose of creating monetized online content.',
#   'output': ' Was the impression he was giving to a text message sent to his mother \n Also, from what I was reading, they would actually force him to do this sometimes monetarily \n Like, they would financially pressure him to participate in their abuse and mistreatment \n And from the very good go, it feels like they manipulated a mentally vulnerable, vulnerable man who was looking for friends into being their guinea pig to just beat on stream for content to make money off of it'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The individual was subjected to treatments akin to a human piñata, where monetary donations from viewers were obtained through exploitative means. There is evidence suggesting the individual did not willingly participate in all activities. Text messages sent by the individual to his mother serve as documentation of these circumstances.',
#   'output': ' They treated this guy like a human piñata where they would hit him until money fell out from like the deranged viewers that were watching and donating and all of that \n There is nothing here that indicates that he was a willing participant for everything \n Yes, he agreed to a certain level of extreme challenges, but clearly not all of it \n Again, we have the text messages that he sent to his mother'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'He frequently expressed reluctance and verbally declined participation multiple times. Despite his refusals, he was compelled to comply. Legal consent for acts constituting torture is generally invalid according to regional laws.',
#   'output': " It's clear he didn't want to do all of it \n And it's clear on stream the amount of times he would say no to things, but they would still force him to eventually just succumb to it and agree \n Also, from what I was reading, I'm not super familiar with the law in the region, but from what I read, you can't even legally consent to being tortured or anything like that in the first place \n So even if he fully agreed to everything, it doesn't seem like you can legally even do that"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Consent cannot be legally given for self-torture. Naruto is a character that has elicited criticism. A ninja from the Hidden Leaf Village has received negative评价。请注意，最后两句的翻译保留了事实陈述但去除了主观色彩和不当言辞。在正式或学术写作中，如维基百科条目，应避免使用贬义词或主观评价。',
#   'output': " You can't legally consent to fucking torture on yourself \n It's just this whole thing is indefensible in my eyes \n Also, Naruto's a bitch \n This loser brings shame to the entire Hidden Leaf Village"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'He filed a cyberbullying complaint with the Paris Prosecutors Office Cyber Hate Division in response to harassment received following allegations of his abusive treatment towards John Parmanov.',
#   'output': " He has ruined the Uzumaki name with this \n He has filed a cyberbullying complaint amid the backlash to all of this \n He has the call to file a cyberbullying complaint about his feelings being hurt with people insulting him for all of the abuse that he subjected John Parmanov to \n So he filed the complaint to the Paris Prosecutors Office Cyber Hate Division targeting those who have harassed Naruto since JP's death"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Naruto, who is undergoing a period of mourning, has become the target of a cyberbullying campaign. These actions are considered criminal offenses. A complaint will be submitted to the Cyber Hate Division of the Paris Prosecutors Office in the coming days to identify and prosecute the perpetrators.',
#   'output': ' As he goes through a period of mourning, Naruto is the subject of a cyberbullying campaign \n These behaviors, in addition to being immoral, constitute criminal offenses \n A complaint will be filed in the coming days with the Paris Prosecutors Office Cyber Hate Division so that the perpetrators can be identified and prosecuted \n You fucking vile worms'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "Torture and abuse of an individual were broadcast on streams. Following the individual's death, the perpetrators claimed to be victims of emotional harm and defended themselves as being innocent and close associates of the individual.",
#   'output': " Imagine torturing a man for so long, so much mistreatment and abuse broadcast on streams you can make money off of this man's misery \n And now when that man passes away, you are now trying to play the victim yourself like, oh, you guys are hurting our feelings \n How can you guys be mean to us? We've done nothing wrong \n Those are best friends"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "In the final moments depicted in Naruto's post and apology, Naruto threw a water bottle at JP's motionless body on the floor and slapped it to check for any response, ultimately confirming JP's death. Throughout the marathon stream, there were instances of abusive behavior towards JP by Naruto.",
#   'output': " Did you not read our heartfelt post where we called him? Well, where Naruto called him his sidekick? Did you also not read the part in Naruto's apology? That was so heartfelt where he said, please stop sharing the final moments \n Oh, man, what did you miss all of that? Because the final moments make them look so bad because in the final moments he throws a fucking water bottle at JP's lifeless body on the floor and then goes and slaps it to see if he'll be responsive only to find out he's dead \n Because for the entirety of that marathon stream, they're just abusing this poor guy \n What? Oh my god, did you miss all of that? It's so clear how much they love their best friend"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'Instances of harassment towards individuals, such as those directed at Naruto and Safinay through negative comments, require identification and appropriate action to address the misconduct.',
#   'output': " You guys are being mean to them \n That's crazy \n Oh my god \n What does the world come to? We need to identify and prosecute everyone who's left a nasty comment about Naruto and Safinay"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The story has been described as highly unpleasant, and there is a hope for punitive actions to follow.',
#   'output': " It's so fucking cringe \n It's crazy \n It is just craziness \n This story has been so fucking gross and I can only pray that they actually do face punishment here"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'French authorities had taken them into custody earlier this year regarding their treatment of John Parminov on stream; however, they were released on the same day. They have continued their actions, appearing to act within legal boundaries in France.',
#   'output': " Because now I'm starting to worry that they won't \n It looks like they might get away with it \n I also learned that they'd actually been taken in by French authorities earlier this year about everything they were putting John Parminov through on stream, but they were released the same day \n And then it ultimately leads to what happened here, where they continue to do it because it looks like they're completely in the right legally over there in France"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'John Parminov, aged 46, passed away under tragic circumstances following continuous mistreatment that was aired on a live stream. The incidents occurred in France, and details are subject to translation from French sources, which may affect the accuracy of information dissemination.',
#   'output': " I guess to continue mistreating this guy so they go continue to do it on stream and it leads to a fucking tragedy with the passing of John Parminov at 46 years old \n This shit is so evil \n Now again, all of this is happening in France, so a lot of the information that I get access to is through translations \n So it is a little hard to keep up with everything, like fully accurately, but I'm doing the best I can"},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': "Raphael Groven's story is marked by unfortunate circumstances.",
#   'output': ' It is just so sad \n Like this whole story of Raphael Groven is just so sad, man \n Like it breaks my heart to see this kind of shit \n Anyway, I just wanted to talk about it'},
#  {'instruction': 'Re-write the following in the tone of x0rv',
#   'input': 'The phrase "See ya" is an informal way of saying goodbye.',
#   'output': ' See ya \n'}]

# %%
def transform_to_conversations(data):
    transformed_data = []

    for item in data:
        # Create the conversation format
        conversations = [
            {
                "content": item["instruction"]
                + ("\n\n" + item["input"] if item["input"].strip() else ""),
                "role": "user",
            },
            {"content": item["output"], "role": "assistant"},
        ]

        transformed_item = {
            "conversations": conversations,
            "source": "custom_tone_training",  # You can customize this
            "score": 1.0,  # You can set a default score or calculate one
        }

        transformed_data.append(transformed_item)

    return transformed_data


# Transform your data
transformed_data = transform_to_conversations(data)
print("Transformed format:", transformed_data[0])
# Out:
# Transformed format: {'conversations': [{'content': 'Re-write the following in the tone of x0rv\n\nA text thread was received from Matt in the morning, considered to be particularly noteworthy and appealing.', 'role': 'user'}, {'content': "Here's something I haven't done in a long, long time \n A text thread \n This puppy is something Matt sent me this morning and it's special \n It is irresistible", 'role': 'assistant'}], 'source': 'custom_tone_training', 'score': 1.0}

# %%
from datasets import Dataset
from unsloth.chat_templates import standardize_data_formats

# Create a Dataset object
dataset = Dataset.from_list(transformed_data)

# Apply unsloth's standardization
dataset = standardize_data_formats(dataset)

# Check the result
print("Final format:", dataset[0])
# Out:
# Unsloth: Standardizing formats (num_proc=16):   0%|          | 0/722 [00:00<?, ? examples/s]
# Final format: {'conversations': [{'content': 'Re-write the following in the tone of x0rv\n\nA text thread was received from Matt in the morning, considered to be particularly noteworthy and appealing.', 'role': 'user'}, {'content': "Here's something I haven't done in a long, long time \n A text thread \n This puppy is something Matt sent me this morning and it's special \n It is irresistible", 'role': 'assistant'}], 'source': 'custom_tone_training', 'score': 1.0}

# %% [markdown]
# Let's see how row 100 looks like!

# %%
dataset[100]
# Out:
# {'conversations': [{'content': 'What is the modulus operator in programming and how can I use it to calculate the modulus of two given numbers?',
#    'role': 'user'},
#   {'content': 'In programming, the modulus operator is represented by the \'%\' symbol. It calculates the remainder when one number is divided by another. To calculate the modulus of two given numbers, you can use the modulus operator in the following way:\n\n```python\n# Calculate the modulus\nModulus = a % b\n\nprint("Modulus of the given numbers is: ", Modulus)\n```\n\nIn this code snippet, the variables \'a\' and \'b\' represent the two given numbers for which you want to calculate the modulus. By using the modulus operator \'%\', we calculate the remainder when \'a\' is divided by \'b\'. The result is then stored in the variable \'Modulus\'. Finally, the modulus value is printed using the \'print\' statement.\n\nFor example, if \'a\' is 10 and \'b\' is 4, the modulus calculation would be 10 % 4, which equals 2. Therefore, the output of the above code would be:\n\n```\nModulus of the given numbers is: 2\n```\n\nThis means that the modulus of 10 and 4 is 2.',
#    'role': 'assistant'}],
#  'source': 'infini-instruct-top-500k',
#  'score': 4.774171352386475}

# %% [markdown]
# We now have to apply the chat template for `Gemma-3` onto the conversations, and save it to `text`. We remove the `<bos>` token using removeprefix(`'<bos>'`) since we're finetuning. The Processor will add this token before training and the model expects only one.

# %%
def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [
        tokenizer.apply_chat_template(
            convo, tokenize=False, add_generation_prompt=False
        ).removeprefix("<bos>")
        for convo in convos
    ]
    return {
        "text": texts,
    }


dataset = dataset.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/722 [00:00<?, ? examples/s]

# %% [markdown]
# Let's see how the chat template did! Notice there is no `<bos>` token as the processor tokenizer will be adding one.

# %%
dataset[100]["text"]
# Out:
# "<start_of_turn>user\nRe-write the following in the tone of x0rv\n\nThe individual appeared to be distracted in another direction when the incident occurred. The location has been identified as a frequent spot for thefts involving Pokémon card collections.<end_of_turn>\n<start_of_turn>model\nBecause it looks like she was looking in the other direction when he made his big move there \n Anyway, I want to show you another Pokemon thief \n So that's how it's going to be \n This is the hotspot for stealing Pokemon cards<end_of_turn>\n"

# %%
len(dataset)
# Out:
# 722

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTTrainer, SFTConfig

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    eval_dataset=None,  # Can set up evaluation!
    args=SFTConfig(
        dataset_text_field="text",
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,  # Use GA to mimic batch size!
        warmup_steps=5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps=60,
        learning_rate=2e-4,  # Reduce to 2e-5 for long training runs
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        report_to="none",  # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/722 [00:00<?, ? examples/s]

# %% [markdown]
# We also use Unsloth's `train_on_completions` method to only train on the assistant outputs and ignore the loss on the user's inputs. This helps increase accuracy of finetunes!

# %%
from unsloth.chat_templates import train_on_responses_only

trainer = train_on_responses_only(
    trainer,
    instruction_part="<start_of_turn>user\n",
    response_part="<start_of_turn>model\n",
)
# Out:
# Map (num_proc=16):   0%|          | 0/722 [00:00<?, ? examples/s]

# %% [markdown]
# Let's verify masking the instruction part is done! Let's print the 100th row again.  Notice how the sample only has a single `<bos>` as expected!

# %%
tokenizer.decode(trainer.train_dataset[100]["input_ids"])
# Out:
# "<bos><start_of_turn>user\nRe-write the following in the tone of x0rv\n\nThe individual appeared to be distracted in another direction when the incident occurred. The location has been identified as a frequent spot for thefts involving Pokémon card collections.<end_of_turn>\n<start_of_turn>model\nBecause it looks like she was looking in the other direction when he made his big move there \n Anyway, I want to show you another Pokemon thief \n So that's how it's going to be \n This is the hotspot for stealing Pokemon cards<end_of_turn>\n"

# %% [markdown]
# Now let's print the masked out example - you should see only the answer is present:

# %%
tokenizer.decode(
    [
        tokenizer.pad_token_id if x == -100 else x
        for x in trainer.train_dataset[100]["labels"]
    ]
).replace(tokenizer.pad_token, " ")
# Out:
# "                                                    Because it looks like she was looking in the other direction when he made his big move there \n Anyway, I want to show you another Pokemon thief \n So that's how it's going to be \n This is the hotspot for stealing Pokemon cards<end_of_turn>\n"

# %%
import torch

torch._dynamo.config.suppress_errors = True
torch._dynamo.config.disable = True

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA GeForce RTX 3060. Max memory = 11.622 GB.
# 1.191 GB of memory reserved.

# %% [markdown]
# # Let's train the model!
#
# To resume a training run, set `trainer.train(resume_from_checkpoint = True)`

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 722 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 4 x 1) = 4
#  "-____-"     Trainable parameters = 6,522,880 of 1,006,408,832 (0.65% trained)
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 01:01, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.592600</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.570800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.916300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.309900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.312000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.068600</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.247000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.751900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.276800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.582500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.052100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.793400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>3.292300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.614100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.036700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.290000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3.427700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.135400</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.906100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.186300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.108800</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.215300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.961800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.503700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.426200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.626700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.483700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.971800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.088700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.529100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>2.889100</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.659200</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.746600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.216500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.855100</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>3.029100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.645300</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.955900</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>3.063300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.547600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.853100</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.798800</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.777200</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.759000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.580400</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>2.655600</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>3.072700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.002100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.868400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.923600</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>2.609900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>2.511200</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.568900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>3.039700</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.330400</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>3.302000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>2.721500</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.768200</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.322500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.767500</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Will smartly offload gradients to save VRAM!

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 66.4925 seconds used for training.
# 1.11 minutes used for training.
# Peak reserved memory = 1.191 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 10.248 %.
# Peak reserved memory for training % of max memory = 0.0 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model via Unsloth native inference! According to the `Gemma-3` team, the recommended settings for inference are `temperature = 1.0, top_p = 0.95, top_k = 64`

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template="gemma-3",
)
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "Continue the sequence: 1, 1, 2, 3, 5, 8,",
            }
        ],
    }
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,  # Must add for generation
    return_tensors="pt",
    tokenize=True,
    return_dict=True,
).to("cuda")
outputs = model.generate(
    **inputs,
    max_new_tokens=64,  # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature=1.0,
    top_p=0.95,
    top_k=64,
)
tokenizer.batch_decode(outputs)
# Out:
# ['<bos><start_of_turn>user\nContinue the sequence: 1, 1, 2, 3, 5, 8,<end_of_turn>\n<start_of_turn>model\n14 \n1 \n 2 \n 3 \n 5 \n 8 \n 16 \n 20 \n 30 \n 42 \n 70 \n 90 \n 120 \n 150 ']

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "Re-write the following in the tone of x0rv: \n\n ",
            }
        ],
    }
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,  # Must add for generation
    return_tensors="pt",
    tokenize=True,
    return_dict=True,
).to("cuda")

from transformers import TextStreamer

_ = model.generate(
    **inputs,
    max_new_tokens=64,  # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature=1.0,
    top_p=0.95,
    top_k=64,
    streamer=TextStreamer(tokenizer, skip_prompt=True),
)
# Out:
#  That sky is just so blue today
#  It is hard to figure out why it looks like that
#  I don't know anything about it<end_of_turn>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("gemma-3n_charlie")  # Local saving
tokenizer.save_pretrained("gemma-3n_charlie")
# model.push_to_hub("HF_ACCOUNT/gemma-3", token = "...") # Online saving
# tokenizer.push_to_hub("HF_ACCOUNT/gemma-3", token = "...") # Online saving
# Out:
# ('gemma-3n_charlie/tokenizer_config.json',
#  'gemma-3n_charlie/special_tokens_map.json',
#  'gemma-3n_charlie/chat_template.jinja',
#  'gemma-3n_charlie/tokenizer.model',
#  'gemma-3n_charlie/added_tokens.json',
#  'gemma-3n_charlie/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastModel

    model, tokenizer = FastModel.from_pretrained(
        model_name="lora_model",  # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length=2048,
        load_in_4bit=True,
    )

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "What is Gemma-3N?",
            }
        ],
    }
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,  # Must add for generation
    return_tensors="pt",
    tokenize=True,
    return_dict=True,
).to("cuda")

from transformers import TextStreamer

_ = model.generate(
    **inputs,
    max_new_tokens=128,  # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature=1.0,
    top_p=0.95,
    top_k=64,
    streamer=TextStreamer(tokenizer, skip_prompt=True),
)
# Out:
# Gemma-3N is a **new open-weight large language model (LLM)** developed by **Google DeepMind**. It's designed to be **accessible to a wider range of users**, including researchers and developers, by being **open-weight**. This means the model's weights are publicly available, allowing for more experimentation and customization.
#
# Here's a breakdown of what Gemma-3N is:
#
# * **Large Language Model (LLM):** Gemma-3N is a powerful AI model trained on a massive dataset of text and code. This allows it to understand and generate human-like text, translate

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly for deployment! We save it in the folder `gemma-3N-finetune`. Set `if False` to `if True` to let it run!

# %%
if False:  # Change to True to save finetune!
    model.save_pretrained_merged("gemma-3N-finetune", tokenizer)

# %% [markdown]
# If you want to upload / push to your Hugging Face account, set `if False` to `if True` and add your Hugging Face token and upload location!

# %%
if False:  # Change to True to upload finetune
    model.push_to_hub_merged("HF_ACCOUNT/gemma-3N-finetune", tokenizer, token="hf_...")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now for all models! For now, you can convert easily to `Q8_0, F16 or BF16` precision. `Q4_K_M` for 4bit will come later!

# %%
if False:  # Change to True to save to GGUF
    model.save_pretrained_gguf(
        "gemma-3N-finetune",
        quantization_type="Q8_0",  # For now only Q8_0, BF16, F16 supported
    )

# %% [markdown]
# Likewise, if you want to instead push to GGUF to your Hugging Face account, set `if False` to `if True` and add your Hugging Face token and upload location!

# %%
if False:  # Change to True to upload GGUF
    model.push_to_hub_gguf(
        "gemma-3N-finetune",
        quantization_type="Q8_0",  # Only Q8_0, BF16, F16 supported
        repo_id="HF_ACCOUNT/gemma-3N-finetune-gguf",
        token="hf_...",
    )

# %% [markdown]
# Now, use the `gemma-3N-finetune.gguf` file or `gemma-3N-finetune-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
