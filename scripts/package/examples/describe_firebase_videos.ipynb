# %%
# Train model to speak like penguinz0
# Generate transcripts for firebase's videos in srt format
# Generate cuts and summarize what is happening in cuts for firebase's videos
# Convert srt transcripts to penguinz0's style
# Train model to generate descriptions of cuts given transcript spoken in penguinz0's style
# Actually generate videos
# Generate audio
# Stich together cuts
# ???
# Profit
